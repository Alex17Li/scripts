# %%
import pandas as pd

# %%
edata = pd.read_csv('/mnt/sandbox1/alex.li/find_mislabeled_data_halo_62/evenhash/viz/mislabel_result.csv')
odata = pd.read_csv('/mnt/sandbox1/alex.li/find_mislabeled_data_halo_62/oddhash/viz/mislabel_result.csv')
data = pd.concat([edata, odata])

# %%
data[data['for_traig']]
# Out:
#                                       id      loss  for_triage reasons
# 0       64d26aefc5e3eebecd518753_T02_T03  0.000834       False      []
# 1       64d26eeecdddad3864b7d845_T02_T03  0.000405       False      []
# 2       64d27c5cf32c2602c3a479df_T02_T03  0.002470       False      []
# 3       64d27f5e4210b6d080dbe606_T02_T03  0.000365       False      []
# 4       64d2832fcdddad3864b815d8_T02_T03  0.000747       False      []
# ...                                  ...       ...         ...     ...
# 126611  6580e2e5d80e377564de06d0_I02_I04  0.000986       False      []
# 126612  6580e1e20eb448e301311888_I02_I04  0.003223       False      []
# 126613  65810a1ef62c68a8f6d27c98_I02_I04  0.001638       False      []
# 126614  6580df498b9efca72f9bb221_I02_I04  0.047901       False      []
# 126615  64d4361877a3f6f6309d3564_I02_I04  0.000337       False      []
#
# [252744 rows x 4 columns]
