# %%
from brtdevkit.data import Dataset
import numpy as np
df = Dataset.retrieve(name='Jupiter_20231004_implement_fps').to_dataframe()
velocities = np.array([d['speed'] for d in df['gps_can_data'] if 'speed' in d])
len(df) # 993
len(velocities) # 485, much data has no speed. 98% of this has speed > 0.
# Out:
# 2023-10-10 13:44:12,591 - APIRequestor - ERROR - API error received | error_code : 403, error_message : {'extra': {'role_name': 'token_exchange'}, 'message': 'Role token_exchange is required to make this API call'}
# ERROR:APIRequestor:API error received | error_code : 403, error_message : {'extra': {'role_name': 'token_exchange'}, 'message': 'Role token_exchange is required to make this API call'}
# WARNING:root:Failed to refresh AWS Credential
# WARNING:root:Some functionalities (S3, Athena, etc) not useable {'extra': {'role_name': 'token_exchange'}, 'message': 'Role token_exchange is required to make this API call'}
# 485

# %%
print(len(df))
df = df[df['bag_name'] != '10_04_2023-22_31_14']
print(len(df))
# Out:
# 993
# 742

# %%
df
# Out:
#     artifact_debayeredrgb_0__id artifact_debayeredrgb_0_content_hash  \
# 125    651f0dd0f804810b52e49b4b     8e757f021ecf1ef3e82f7d4fef811b9f
# 126    651f0dd29b8292c23c05c863     465a2c307f9135106124066acad3141c
# 127    651f0dd6c48b6dcce7e6074b     3e1e2d09409593d6aae2c051fd697942
# 128    651f0dd9175cb32bec52dbe5     5f8c077af20515aafb6c5fd89f011317
# 129    651f0ddb7a541635a347f335     e2d1117ac7589f9795c20f3ee59b8a20
# ..                          ...                                  ...
# 988    651f1e1dee1ec5b92f34af0c     dae3805d028583269921e06e2e1246e0
# 989    651f1e1e57a1ce7a997a44d8     16fbb7e5bf08c8d6fafdd175a70679dc
# 990    651f1e23bb3558c32636edd4     865556b528b221cd698ebaa200b87c94
# 991    651f1e26b9d7471817d56e66     8af0cf2186282a8ae4d784e940541738
# 992    651f1e278f8e7829f309a420     658214b022e7bb3246382be53055d045
#
#     artifact_debayeredrgb_0_created_at artifact_debayeredrgb_0_data_category  \
# ...
